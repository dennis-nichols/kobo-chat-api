# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
from collections import deque
from html.parser import HTMLParser
from urllib.parse import urlparse
import os

# Regex pattern to match a URL
HTTP_URL_PATTERN = r'^http[s]*://.+'

# Define root domain to crawl
domain = "support.kobotoolbox.org"
full_url = "https://support.kobotoolbox.org/"

# Create a class to parse the HTML and get the hyperlinks
class HyperlinkParser(HTMLParser):
    def __init__(self):
        super().__init__()
        # Create a list to store the hyperlinks
        self.hyperlinks = []

    # Override the HTMLParser's handle_starttag method to get the hyperlinks
    def handle_starttag(self, tag, attrs):
        attrs = dict(attrs)

        # If the tag is an anchor tag and it has an href attribute, add the href attribute to the list of hyperlinks
        if tag == "a" and "href" in attrs:
            self.hyperlinks.append(attrs["href"])

# Function to get the hyperlinks from a URL
def get_hyperlinks(url):
    
    # Try to open the URL and read the HTML
    try:
        # Open the URL and read the HTML
        with urllib.request.urlopen(url) as response:

            # If the response is not HTML, return an empty list
            if not response.info().get('Content-Type').startswith("text/html"):
                return []
            
            # Decode the HTML
            html = response.read().decode('utf-8')
    except Exception as e:
        print(e)
        return []

    # Create the HTML Parser and then Parse the HTML to get hyperlinks
    parser = HyperlinkParser()
    parser.feed(html)

    return parser.hyperlinks

# Function to get the hyperlinks from a URL that are within the same domain
def get_domain_hyperlinks(local_domain, url):
    clean_links = []
    for link in set(get_hyperlinks(url)):
        clean_link = None

        # If the link is a URL, check if it is within the same domain
        if re.search(HTTP_URL_PATTERN, link):
            # Parse the URL and check if the domain is the same
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain:
                clean_link = link

        # If the link is not a URL, check if it is a relative link
        else:
            if link.startswith("/"):
                link = link[1:]
            elif link.startswith("#") or link.startswith("mailto:"):
                continue
            clean_link = "https://" + local_domain + "/" + link

        if clean_link is not None:
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            clean_links.append(clean_link)

    # Return the list of hyperlinks that are within the same domain
    return list(set(clean_links))


def crawl(url):
    # Parse the URL and get the domain
    local_domain = urlparse(url).netloc

    # Create a queue to store the URLs to crawl
    queue = deque([url])

    # Create a set to store the URLs that have already been seen (no duplicates)
    seen = set([url])

    # Create a directory to store the text files
    if not os.path.exists("text/"):
            os.mkdir("text/")

    if not os.path.exists("text/"+local_domain+"/"):
            os.mkdir("text/" + local_domain + "/")

    # Create a directory to store the csv files
    if not os.path.exists("processed"):
            os.mkdir("processed")

    # While the queue is not empty, continue crawling
    while queue:

        # Get the next URL from the queue
        url = queue.pop()
        print(url) # for debugging and to see the progress

        # Save text from the url to a <url>.txt file
        with open('text/'+local_domain+'/'+url[8:].replace("/", "_") + ".txt", "w") as f:

            # Get the text from the URL using BeautifulSoup
            soup = BeautifulSoup(requests.get(url).text, "html.parser")

            # Get the text but remove the tags
            text = soup.get_text()

            # If the crawler gets to a page that requires JavaScript, it will stop the crawl
            if ("You need to enable JavaScript to run this app." in text):
                print("Unable to parse page " + url + " due to JavaScript being required")
            
            # Otherwise, write the text to the file in the text directory
            f.write(text)

        # Get the hyperlinks from the URL and add them to the queue
        for link in get_domain_hyperlinks(local_domain, url):
            if link not in seen:
                queue.append(link)
                seen.add(link)

crawl(full_url)
# Out:
# https://support.kobotoolbox.org/
# https://support.kobotoolbox.org/manual_upload.html#exporting-data-from-kobocollect
# https://support.kobotoolbox.org/index.html
# https://support.kobotoolbox.org/photo_audio_video_file.html#appearance-of-photo-audio-video-and-file-question-types
# https://support.kobotoolbox.org/./_static/files/photo_audio_video_file/media_question_types.xlsx
# https://support.kobotoolbox.org/encrypting_forms.html
# https://support.kobotoolbox.org/data_through_webforms.html#why-do-i-need-web-forms-instead-of-kobocollect-android-app
# https://support.kobotoolbox.org/merging_dataset_excel_power_query.html#differences-between-individual-data-and-roster-data
# https://support.kobotoolbox.org/./_static/files/merging_dataset_excel_power_query/repeat_group_(merge)_dataset.xlsx
# https://support.kobotoolbox.org/./_static/files/merging_dataset_excel_power_query/repeat_group_(merge).xlsx
# https://support.kobotoolbox.org/restrict_responses.html#examples-related-to-use-of-numbers
# https://support.kobotoolbox.org/quick_start.html#create-your-first-form
# https://support.kobotoolbox.org/software_architecture.html
# https://support.kobotoolbox.org/acknowledge.html#how-it-is-displayed-in-web-forms-and-kobocollect
# https://support.kobotoolbox.org/./_static/files/acknowledge/acknowledge.xlsx
# https://support.kobotoolbox.org/collecting_signatures.html#create-a-signature-question-type-in-the-formbuilder
# https://support.kobotoolbox.org/matrix_response.html
# https://support.kobotoolbox.org/welcome.html#who-is-behind-kobotoolbox
# https://support.kobotoolbox.org/hxl.html#what-exactly-is-hxl
# https://support.kobotoolbox.org/select_one_and_select_many.html#translating-question-and-choice-labels
# https://support.kobotoolbox.org/media.html
# https://support.kobotoolbox.org/./_static/files/media/xlsform-example-media.zip
# https://support.kobotoolbox.org/./_static/files/media/xlsform-example.xls
# https://support.kobotoolbox.org/export_download.html#value-and-header-format
# https://support.kobotoolbox.org/rating_ranking.html#how-to-add-a-rating-question
# https://support.kobotoolbox.org/recording-interviews.html#ethical-considerations
# https://support.kobotoolbox.org/restrict_responses.html#examples-related-to-use-of-time-inputs
# https://support.kobotoolbox.org/restrict_responses.html#examples-related-to-use-of-letters
# https://support.kobotoolbox.org/getting_started_xlsform.html#uploading-and-previewing-the-xlsform-in-kobotoolbox
# https://support.kobotoolbox.org/acknowledge.html#using-skip-logic-and-validation-criteria
# https://support.kobotoolbox.org/kobocollect-android.html#form-management-settings-in-kobocollect
# https://support.kobotoolbox.org/enketo.html#what-are-the-general-features
# https://support.kobotoolbox.org/transferring_forms.html#troubleshooting
# https://support.kobotoolbox.org/overview_of_creating_a_project.html#previewing-the-form
# https://support.kobotoolbox.org/add_questions_library.html
# HTTP Error 404: Not Found
# https://support.kobotoolbox.org/hxl.html#how-to-use-the-hxl-feature-in-the-formbuilder
# https://support.kobotoolbox.org/export_gps.html
# https://support.kobotoolbox.org/collect_gps.html#accuracy-of-the-collected-gps-coordinates
# https://support.kobotoolbox.org/recording-interviews.html#activating-background-audio-recording-in-the-formbuilder
# https://support.kobotoolbox.org/language_xls.html#translating-to-tamil-nepali-hindi-etc-scripts
# https://support.kobotoolbox.org/data_through_webforms.html#troubleshooting-web-forms
# https://support.kobotoolbox.org/public_collections_advanced_search.html
# https://support.kobotoolbox.org/p_codes.html
# https://support.kobotoolbox.org/photo_audio_video_file.html
# https://support.kobotoolbox.org/synchronous_exports.html#authentication
# https://support.kobotoolbox.org/converting_to_spss_and_stata.html#converting-to-spss
# https://support.kobotoolbox.org/using_public_collections.html#locating-the-public-collections
# https://support.kobotoolbox.org/calculations_constraints_matrix.html#setting-up-the-question-and-fields
# https://support.kobotoolbox.org/./_static/files/calculations_constraints_matrix/calculations_constraints_matrix.xlsx
# https://support.kobotoolbox.org/new_form.html
# https://support.kobotoolbox.org/public_collections_advanced_search.html#using-the-query-parser
# https://support.kobotoolbox.org/restrict_responses.html#examples-related-to-the-restriction-of-valid-email-inputs
# https://support.kobotoolbox.org/collect_gps.html#collecting-data-using-kobocollect
# https://support.kobotoolbox.org/number_text_responses.html
# https://support.kobotoolbox.org/kobotoolbox_interface.html#search-bar
# https://support.kobotoolbox.org/question_options.html#data-column-name
# https://support.kobotoolbox.org/select_one_and_select_many.html#xml-values
# https://support.kobotoolbox.org/software_architecture.html#high-level-server-side-overview
# https://support.kobotoolbox.org/kobocollect-android.html#locking-kobocollect-with-an-admin-password
# https://support.kobotoolbox.org/public_collections_advanced_search.html#understanding-the-search-field-syntax
# https://support.kobotoolbox.org/server.html
# https://support.kobotoolbox.org/group_repeat.html#alternative-way-of-creating-a-group
# https://support.kobotoolbox.org/formbuilder.html#adding-a-question
# https://support.kobotoolbox.org/gdpr.html#requesting-to-be-forgotten
# https://support.kobotoolbox.org/transcription-translation.html#how-to-add-translations
# https://support.kobotoolbox.org/date_time.html#how-to-set-up-date-and-time-question-types
# https://support.kobotoolbox.org/./_static/files/date_time/date_time.xlsx
# https://support.kobotoolbox.org/deploy_form_new_project.html#redeploying-your-form
# https://support.kobotoolbox.org/delete_project.html#deleting-projects-from-your-project-dashboard
# https://support.kobotoolbox.org/pulling_data_into_excelquery.html#troubleshooting
# https://support.kobotoolbox.org/getting_started_xlsform.html#adding-settings
# https://support.kobotoolbox.org/archiving_projects.html#process-of-archiving
# https://support.kobotoolbox.org/calculations_constraints_matrix.html#viewing-the-result
# https://support.kobotoolbox.org/restrict_responses.html#considerations-when-using-regex
# https://support.kobotoolbox.org/select_one_and_select_many.html#when-to-use-them
# https://support.kobotoolbox.org/formbuilder.html
# https://support.kobotoolbox.org/howto_edit_multiple_submissions.html
# https://support.kobotoolbox.org/number_decimal_range.html#advanced-appearances
# https://support.kobotoolbox.org/./_static/files/number_decimal_range/number_decimal_range_question_types.xlsx
# https://support.kobotoolbox.org/xls_url.html#dropbox
# https://support.kobotoolbox.org/unique_serial_numbers.html
# https://support.kobotoolbox.org/question_options.html#mandatory-response
# https://support.kobotoolbox.org/cascading_select.html#adding-cascading-question-sets-in-xlsform-option-1
# https://support.kobotoolbox.org/dynamic_data_attachment.html#understanding-the-syntax-used-in-the-calculation-column-of-the-child-project
# https://support.kobotoolbox.org/./_static/files/dynamic_data_attachment/Round_1.xlsx
# https://support.kobotoolbox.org/./_static/files/dynamic_data_attachment/Round_2.xlsx
# https://support.kobotoolbox.org/recording-interviews.html
# https://support.kobotoolbox.org/using_public_collections.html#purpose-of-the-public-collections
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#locking-kobocollect-with-an-admin-password
# https://support.kobotoolbox.org/transcription-translation.html
# https://support.kobotoolbox.org/delete_project.html#deleting-projects-from-the-project-settings-page
# https://support.kobotoolbox.org/kobocollect-android.html
# https://support.kobotoolbox.org/form_meta.html#background-audio
# https://support.kobotoolbox.org/./_static/files/form_meta/form_meta.xlsx
# https://support.kobotoolbox.org/overview_of_creating_a_project.html#adding-questions
# https://support.kobotoolbox.org/gdpr.html
# https://support.kobotoolbox.org/kobocollect-android.html#collecting-data-in-kobocollect
# https://support.kobotoolbox.org/hxl.html
# https://support.kobotoolbox.org/is_my_data_safe.html#integrity
# https://support.kobotoolbox.org/overview_of_creating_a_project.html#creating-your-first-form
# https://support.kobotoolbox.org/managing_permissions.html#copy-permissions-from-another-project
# https://support.kobotoolbox.org/getting_started_xlsform.html#replacing-a-form-with-an-xlsform-file
# https://support.kobotoolbox.org/number_decimal_range.html#translating-question-labels
# https://support.kobotoolbox.org/media.html#step-2-add-media-columns-to-your-xlsform
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#setting-up-metadata-in-kobocollect
# https://support.kobotoolbox.org/row_level_permissions.html#managing-row-level-permissions
# https://support.kobotoolbox.org/recording-interviews.html#troubleshooting
# https://support.kobotoolbox.org/reset_password.html
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#setting-up-blank-forms-in-kobocollect
# https://support.kobotoolbox.org/group_repeat.html#displaying-the-grouped-questions-on-the-same-screen
# https://support.kobotoolbox.org/upload_to_gis.html
# https://support.kobotoolbox.org/media.html#step-3-handling-media-columns-for-multiple-languages
# https://support.kobotoolbox.org/formbuilder.html#adding-questions-to-the-library
# https://support.kobotoolbox.org/select_one_and_select_many.html#setting-up-the-question-and-choices
# https://support.kobotoolbox.org/kobocollect-android.html#setting-up-metadata-in-kobocollect
# https://support.kobotoolbox.org/new_form.html#projects-list
# https://support.kobotoolbox.org/pulling_data_into_powerbi.html
# https://support.kobotoolbox.org/pulling_data_into_powerbi.html#step-2-add-the-data-source
# https://support.kobotoolbox.org/encrypting_forms.html#how-it-works
# https://support.kobotoolbox.org/select_one_and_select_many.html#how-they-are-displayed-by-default-on-web-forms-and-kobocollect
# https://support.kobotoolbox.org/gdpr.html#what-is-gdpr
# https://support.kobotoolbox.org/cascading_select.html#importing-cascading-question-sets-in-the-formbuilder
# https://support.kobotoolbox.org/managing_permissions.html
# https://support.kobotoolbox.org/archiving_projects.html#purpose-of-archiving
# https://support.kobotoolbox.org/howto_edit_multiple_submissions.html#editing-blank-responses-for-multiple-submissions
# https://support.kobotoolbox.org/gps_questions.html#calculating-distance-and-area-with-line-and-area-question-types
# https://support.kobotoolbox.org/./_static/files/gps_questions/gps_questions.xlsx
# https://support.kobotoolbox.org/data-collection-tools.html
# https://support.kobotoolbox.org/creating_account.html#creating-an-account
# https://support.kobotoolbox.org/text_and_note.html#appearance-in-web-forms-and-kobocollect
# https://support.kobotoolbox.org/photo_audio_video_file.html#lowering-the-file-size-of-collected-media
# https://support.kobotoolbox.org/kobocollect-android.html#uploading-finalized-data-to-the-server
# https://support.kobotoolbox.org/lower_file_size.html
# https://support.kobotoolbox.org/date_time.html#appearance-of-date-and-time-question-types-in-web-forms-and-kobocollect
# https://support.kobotoolbox.org/number_decimal_range.html#setting-up-in-formbuilder
# https://support.kobotoolbox.org/kobocollect-android.html#editing-data-in-kobocollect
# https://support.kobotoolbox.org/number_decimal_range.html#when-to-use-them
# https://support.kobotoolbox.org/photo_audio_video_file.html#limiting-accepted-file-types-for-file-question-type
# https://support.kobotoolbox.org/data_through_webforms.html#what-are-web-forms
# https://support.kobotoolbox.org/rating_ranking.html#difference-between-rating-and-ranking-questions
# https://support.kobotoolbox.org/transcription-translation.html#language-list
# https://support.kobotoolbox.org/library_locking.html#xlsform-configuration
# https://support.kobotoolbox.org/_static/files/library_locking/library-locking-example.xlsx
# https://support.kobotoolbox.org/row_level_permissions.html#configure-your-account-settings
# https://support.kobotoolbox.org/enketo.html#how-can-i-access-enketo-when-on-kobotoolbox
# https://support.kobotoolbox.org/export_gps.html#how-to-share-map-data
# https://support.kobotoolbox.org/custom_format_web.html#combining-text-and-media-by-combining-subsequent-notes
# https://support.kobotoolbox.org/troubleshooting_kobocollect.html
# https://support.kobotoolbox.org/rating_ranking.html
# https://support.kobotoolbox.org/text_and_note.html#using-question-logic
# https://support.kobotoolbox.org/restrict_responses.html#how-do-i-build-the-regex-that-i-need
# https://support.kobotoolbox.org/adding_skip_to_matrix.html#kobo-matrix-list-approach
# https://support.kobotoolbox.org/./_static/files/adding_skip_to_matrix/adding_skip_to_a_matrix_question.xls
# https://support.kobotoolbox.org/./_static/files/adding_skip_to_matrix/adding_skip_to_a_matrix_question_kobo_matrix.xls
# https://support.kobotoolbox.org/api.html
# https://support.kobotoolbox.org/training_french.html
# https://support.kobotoolbox.org/using_public_collections.html
# https://support.kobotoolbox.org/select_one_and_select_many.html#advanced-appearances
# https://support.kobotoolbox.org/pulling_data_into_powerbi.html#step-1-get-the-synchronous-exports-url
# https://support.kobotoolbox.org/lower_file_size.html#kobocollect
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#collecting-data-in-kobocollect
# https://support.kobotoolbox.org/question_options.html#appearance-optional
# https://support.kobotoolbox.org/media.html#step-7-collect-data
# https://support.kobotoolbox.org/public_collections_advanced_search.html#valid-search-field-operators
# https://support.kobotoolbox.org/collect_gps.html#collecting-data-using-enketo-webforms
# https://support.kobotoolbox.org/getting_started_xlsform.html#more-xlsform-learning-resources
# https://support.kobotoolbox.org/kobo_local_computer.html
# https://support.kobotoolbox.org/add_logo.html
# https://support.kobotoolbox.org/group_repeat.html#downloading-data-from-repeat-groups
# https://support.kobotoolbox.org/row_level_permissions.html#troubleshooting
# https://support.kobotoolbox.org/troubleshooting_webforms.html#known-issues-with-offline-forms-on-ios
# https://support.kobotoolbox.org/data_storage.html
# https://support.kobotoolbox.org/rating_ranking.html#how-to-add-a-ranking-question-in-the-formbuilder
# https://support.kobotoolbox.org/is_my_data_safe.html#confidentiality
# https://support.kobotoolbox.org/number_decimal_range.html#default-appearance-in-web-forms-and-kobocollect
# https://support.kobotoolbox.org/getting_started_xlsform.html#what-is-xlsform
# https://support.kobotoolbox.org/welcome.html#who-is-kobotoolbox-for
# https://support.kobotoolbox.org/lower_file_size.html#open-camera
# https://support.kobotoolbox.org/data-collection-tools.html#a-quick-rundown-on-the-differences-between-the-two-options
# https://support.kobotoolbox.org/overview_of_creating_a_project.html#deploying-the-form
# https://support.kobotoolbox.org/howto_edit_multiple_submissions.html#limitations-when-editing-responses-for-multiple-submissions
# https://support.kobotoolbox.org/api.html#testing-your-api
# https://support.kobotoolbox.org/alternative_enketo.html
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#resetting-view-sent-form-in-kobocollect
# https://support.kobotoolbox.org/calculate_questions.html
# https://support.kobotoolbox.org/delete_project.html
# https://support.kobotoolbox.org/kobo_your_servers.html
# https://support.kobotoolbox.org/pulling_data_into_excelquery.html
# https://support.kobotoolbox.org/kobocollect-android.html#deleting-saved-forms-in-kobocollect
# https://support.kobotoolbox.org/collecting_signatures.html#collect-android-app
# https://support.kobotoolbox.org/date_time.html#using-date-and-time-questions-in-custom-logic
# https://support.kobotoolbox.org/synchronous_exports.html#limitations
# https://support.kobotoolbox.org/public_collections_advanced_search.html#the-default-search-behaviour
# https://support.kobotoolbox.org/calculate_questions.html#list-of-available-functions
# https://support.kobotoolbox.org/record_validation.html#functionality-overview
# https://support.kobotoolbox.org/overview_of_creating_a_project.html
# https://support.kobotoolbox.org/creating_account.html
# https://support.kobotoolbox.org/collect_gps.html#creating-the-different-types-of-gps-questions
# https://support.kobotoolbox.org/group_repeat.html#nested-repeat-roster-within-a-roster
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#deleting-saved-forms-in-kobocollect
# https://support.kobotoolbox.org/quick_start.html#sign-up-and-login
# https://support.kobotoolbox.org/rest_services.html
# https://support.kobotoolbox.org/restrict_responses.html
# https://support.kobotoolbox.org/xls_url.html#google-sheets
# https://support.kobotoolbox.org/restrict_responses.html#characters-with-accents
# https://support.kobotoolbox.org/media.html#step-6-deploy-form
# https://support.kobotoolbox.org/acknowledge.html#how-to-set-up-the-question
# https://support.kobotoolbox.org/cascading_select.html
# https://support.kobotoolbox.org/converting_to_spss_and_stata.html
# https://support.kobotoolbox.org/gps_questions.html#appearance-of-point-line-and-area-question-types-in-web-forms-and-kobocollect
# https://support.kobotoolbox.org/formbuilder.html#adding-a-question-hint
# https://support.kobotoolbox.org/welcome.html#what-is-the-cost-of-kobotoolbox
# https://support.kobotoolbox.org/collecting_signatures.html
# https://support.kobotoolbox.org/api.html#getting-your-api-token
# https://support.kobotoolbox.org/managing_permissions.html#making-your-project-and-data-public
# https://support.kobotoolbox.org/library_locking.html#json-representation
# https://support.kobotoolbox.org/photo_download.html#including-direct-hyperlinks-to-collected-media-in-xls-export
# https://support.kobotoolbox.org/creating_custom_reports.html#learn-how-to-navigate-and-manage-the-data-in-the-reports-page
# https://support.kobotoolbox.org/welcome.html
# https://support.kobotoolbox.org/project_summary.html
# https://support.kobotoolbox.org/activation_link.html
# https://support.kobotoolbox.org/number_decimal_range.html#limits-on-number-and-decimal-questions
# https://support.kobotoolbox.org/data_through_webforms.html
# https://support.kobotoolbox.org/synchronous_exports.html
# https://support.kobotoolbox.org/select_one_and_select_many.html#export-options
# https://support.kobotoolbox.org/record_validation.html
# https://support.kobotoolbox.org/group_repeat.html#re-ordering-a-question-within-a-group
# https://support.kobotoolbox.org/deploy_form_new_project.html
# https://support.kobotoolbox.org/question_library.html#managing-questions-in-your-library
# https://support.kobotoolbox.org/data-offline.html#what-do-i-do-if-i-have-no-access-to-the-internet
# https://support.kobotoolbox.org/getting_started_xlsform.html#adding-questions
# https://support.kobotoolbox.org/question_options.html#guidance-hint-optional
# https://support.kobotoolbox.org/getting_started_xlsform.html
# https://support.kobotoolbox.org/deploy_form_new_project.html#using-kobocollect
# https://support.kobotoolbox.org/advanced_calculate.html
# https://support.kobotoolbox.org/getting_started_xlsform.html#adding-choices
# https://support.kobotoolbox.org/gdpr.html#security-and-privacy-at-kobotoolbox
# https://support.kobotoolbox.org/library_locking.html
# https://support.kobotoolbox.org/dynamic_data_attachment.html#collecting-and-managing-data-with-dynamic-linking
# https://support.kobotoolbox.org/devices_for_data_collection.html#phones-vs-tablets
# https://support.kobotoolbox.org/creating_account.html#how-to-access-kobotoolbox
# https://support.kobotoolbox.org/form_meta.html#form-metadata
# https://support.kobotoolbox.org/language_xls.html#translating-right-to-left-scripts
# https://support.kobotoolbox.org/matrix_response.html#create-a-question-matrix-in-xlsform
# https://support.kobotoolbox.org/media.html#step-1-download-form-as-xlsform
# https://support.kobotoolbox.org/question_library.html#importing-collections
# https://support.kobotoolbox.org/group_repeat.html#adding-questions-within-a-group
# https://support.kobotoolbox.org/question_options.html
# https://support.kobotoolbox.org/text_and_note.html#how-to-set-the-questions-up
# https://support.kobotoolbox.org/devices_for_data_collection.html#pricing
# https://support.kobotoolbox.org/merging_dataset_excel_power_query.html#troubleshooting
# https://support.kobotoolbox.org/overview_of_creating_a_project.html#entering-data-using-the-web-form
# https://support.kobotoolbox.org/kobocollect-android.html#setting-up-the-server-connection
# https://support.kobotoolbox.org/encrypting_forms.html#how-to-decrypt-forms
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#setting-up-the-server-connection
# https://support.kobotoolbox.org/managing_permissions.html#sharing-a-project-with-other-users-and-setting-their-permissions
# https://support.kobotoolbox.org/export_download.html#exports-stuck-in-pending-state-or-failed
# https://support.kobotoolbox.org/user_specified_other.html
# https://support.kobotoolbox.org/welcome.html#what-is-kobotoolbox-being-used-for
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#editing-data-in-kobocollect
# https://support.kobotoolbox.org/custom_format_web.html
# https://support.kobotoolbox.org/recording-interviews.html#including-background-audio-question-type-in-xlsform
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#form-management-settings-in-kobocollect
# https://support.kobotoolbox.org/restrict_responses.html#examples-related-to-use-of-a-combination-of-letters-and-numbers
# https://support.kobotoolbox.org/group_repeat.html#using-information-to-a-roster-from-a-preceding-roster
# https://support.kobotoolbox.org/photo_audio_video_file.html#background-audio-recording
# https://support.kobotoolbox.org/archiving_projects.html
# https://support.kobotoolbox.org/gps_questions.html
# https://support.kobotoolbox.org/responses_inside_question.html
# https://support.kobotoolbox.org/audit_logging.html
# https://support.kobotoolbox.org/managing_permissions.html#requiring-passwords-for-accessing-enketo-web-forms
# https://support.kobotoolbox.org/library_locking.html#locking-profiles-and-asset-types
# https://support.kobotoolbox.org/kobocollect-android.html#setting-up-blank-forms-in-kobocollect
# https://support.kobotoolbox.org/manual_upload.html#exporting-data-from-web-forms
# https://support.kobotoolbox.org/question_library.html
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#hiding-buttons-in-kobocollect
# https://support.kobotoolbox.org/group_repeat.html#grouping-a-set-of-questions
# https://support.kobotoolbox.org/recovering_previous_formdata.html
# https://support.kobotoolbox.org/video_question_type.html
# https://support.kobotoolbox.org/formbuilder.html#changing-the-order-of-your-questions
# https://support.kobotoolbox.org/howto_edit_multiple_submissions.html#editing-responses-for-multiple-submissions
# https://support.kobotoolbox.org/troubleshooting_webforms.html
# https://support.kobotoolbox.org/skip_logic.html
# https://support.kobotoolbox.org/collecting_signatures.html#enketo
# https://support.kobotoolbox.org/kobotoolbox_interface.html#project-actions
# https://support.kobotoolbox.org/manual_upload.html#importing-a-data-zip-file
# https://support.kobotoolbox.org/export_gps.html#viewing-your-gps-points
# https://support.kobotoolbox.org/group_repeat.html#ungrouping-a-set-of-questions
# https://support.kobotoolbox.org/matrix_response.html#create-a-question-matrix-in-the-formbuilder
# https://support.kobotoolbox.org/question_options.html#default-response-optional
# https://support.kobotoolbox.org/excel_analyzer_guide.html
# https://support.kobotoolbox.org/getting_started_xlsform.html#how-to-set-up-xlsform
# https://support.kobotoolbox.org/pull_data_kobotoolbox.html
# https://support.kobotoolbox.org/collect_gps.html
# https://support.kobotoolbox.org/merging_dataset_excel_power_query.html
# https://support.kobotoolbox.org/dynamic_data_attachment.html
# https://support.kobotoolbox.org/advanced_calculate.html#approaches-towards-adding-calculate-questions
# https://support.kobotoolbox.org/export_download.html
# https://support.kobotoolbox.org/adding_skip_to_matrix.html#the-formbuilder-approach
# https://support.kobotoolbox.org/date_time.html
# https://support.kobotoolbox.org/hipaa_compliance.html
# https://support.kobotoolbox.org/kobotoolbox_interface.html#draft-deployed-and-archived-projects
# https://support.kobotoolbox.org/photo_audio_video_file.html#how-to-set-up-photo-audio-video-and-file-question-types
# https://support.kobotoolbox.org/kobotoolbox_interface.html#user-profile-options
# https://support.kobotoolbox.org/enketo.html
# https://support.kobotoolbox.org/pulling_data_into_powerbi.html#troubleshooting
# https://support.kobotoolbox.org/managing_permissions.html#assigning-add-submissions-rights-for-specific-users
# https://support.kobotoolbox.org/recording-interviews.html#viewing-audio-files-that-were-recorded-as-background-audio
# https://support.kobotoolbox.org/validation_criteria.html#add-validation-criteria-in-formbuilder
# https://support.kobotoolbox.org/validation_criteria.html#add-validation-criteria-in-xlsform
# https://support.kobotoolbox.org/lower_file_size.html#instructions
# https://support.kobotoolbox.org/using_public_collections.html#using-the-public-collections
# https://support.kobotoolbox.org/p_codes.html#example-with-3-admin-levels-using-cascading-lists
# https://support.kobotoolbox.org/getting_started_xlsform.html#downloading-an-xlsform-from-kobotoolbox
# https://support.kobotoolbox.org/using_public_collections.html#related-articles
# https://support.kobotoolbox.org/recording-interviews.html#downloading-audio-files
# https://support.kobotoolbox.org/kobocollect-android.html#differences-between-kobocollect-odk-collect
# https://support.kobotoolbox.org/question_library.html#adding-questions-to-your-library
# https://support.kobotoolbox.org/group_repeat.html#removing-questions-from-a-group
# https://support.kobotoolbox.org/recently_updated.html
# https://support.kobotoolbox.org/group_repeat.html#skipping-a-group-of-questions
# https://support.kobotoolbox.org/transcription-translation.html#how-to-add-transcriptions
# https://support.kobotoolbox.org/creating_custom_reports.html
# https://support.kobotoolbox.org/merging_dataset_excel_power_query.html#merging-individual-data-with-roster-data
# https://support.kobotoolbox.org/advanced_calculate.html#rules-when-working-with-calculate-questions
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#uploading-finalized-data-to-the-server
# https://support.kobotoolbox.org/unique_serial_numbers.html#approach-1-creating-sequential-unique-serial-numbers-based-on-date-and-time
# https://support.kobotoolbox.org/media.html#step-4-replace-xlsform
# https://support.kobotoolbox.org/managing_permissions.html#removing-shared-projects-from-your-account
# https://support.kobotoolbox.org/data_through_webforms.html#forwarding-upon-submission
# https://support.kobotoolbox.org/form_meta.html#form-style
# https://support.kobotoolbox.org/enketo.html#what-ecosystem-does-enketo-use
# https://support.kobotoolbox.org/synchronous_exports.html#steps-to-using-the-synchronous-export-feature
# https://support.kobotoolbox.org/formbuilder.html#deleting-a-question
# https://support.kobotoolbox.org/data_through_webforms.html#how-do-i-use-web-forms-for-data-collection
# https://support.kobotoolbox.org/encrypting_forms.html#generating-rsa-encryption-keys
# https://support.kobotoolbox.org/kobocollect-android.html#resetting-view-sent-form-in-kobocollect
# https://support.kobotoolbox.org/dynamic_data_attachment.html#dynamically-linking-projects-in-xlsform
# https://support.kobotoolbox.org/text_and_note.html
# https://support.kobotoolbox.org/recording-interviews.html#collecting-background-audio-with-collect-android-app
# https://support.kobotoolbox.org/library_locking.html#restrictions
# https://support.kobotoolbox.org/add_logo.html#tips
# https://support.kobotoolbox.org/number_decimal_range.html
# https://support.kobotoolbox.org/row_level_permissions.html
# https://support.kobotoolbox.org/creating_account.html#logging-back-into-kobotoolbox
# https://support.kobotoolbox.org/converting_to_spss_and_stata.html#converting-the-spss-file-into-a-stata-file
# https://support.kobotoolbox.org/devices_for_data_collection.html
# https://support.kobotoolbox.org/formbuilder.html#changing-question-settings
# https://support.kobotoolbox.org/restrict_responses.html#to-use-a-regex-in-kobotoolbox-follow-these-steps
# https://support.kobotoolbox.org/data_through_webforms.html#how-do-i-save-an-offline-web-form-on-a-mobile-device
# https://support.kobotoolbox.org/xls_url.html
# https://support.kobotoolbox.org/acknowledge.html
# https://support.kobotoolbox.org/validation_criteria.html#example-validation-criteria
# https://support.kobotoolbox.org/photo_download.html#for-slow-connections-or-very-large-projects-using-downthemall
# https://support.kobotoolbox.org/kobocollect-android.html#hiding-buttons-in-kobocollect
# https://support.kobotoolbox.org/manual_upload.html
# https://support.kobotoolbox.org/overview_of_creating_a_project.html#viewing-the-data
# https://support.kobotoolbox.org/calculations_constraints_matrix.html#troubleshooting
# https://support.kobotoolbox.org/rating_ranking.html#when-should-you-use-ranking-or-rating-questions
# https://support.kobotoolbox.org/pulling_data_into_powerbi.html#updating-the-data-in-your-reports
# https://support.kobotoolbox.org/kobotoolbox_interface.html#help-legacy-interface-and-source-code
# https://support.kobotoolbox.org/training_arabic.html
# https://support.kobotoolbox.org/language_xls.html
# https://support.kobotoolbox.org/form_meta.html
# https://support.kobotoolbox.org/pulling_data_into_excelquery.html#step-2-add-the-data-source
# https://support.kobotoolbox.org/number_decimal_range.html#setting-up-in-xlsform
# https://support.kobotoolbox.org/language_dashboard.html
# https://support.kobotoolbox.org/is_my_data_safe.html#availability-and-resilience
# https://support.kobotoolbox.org/pulling_data_into_excelquery.html#updating-the-data-in-your-reports
# https://support.kobotoolbox.org/overview_of_creating_a_project.html#downloading-the-data
# https://support.kobotoolbox.org/edit_forms_excel.html
# https://support.kobotoolbox.org/kobotoolbox_interface.html
# https://support.kobotoolbox.org/cascading_select.html#adding-cascading-question-sets-in-xlsform-option-2
# https://support.kobotoolbox.org/group_repeat.html#creating-a-roster-repeating-group-of-questions
# https://support.kobotoolbox.org/welcome.html#what-can-kobotoolbox-do
# https://support.kobotoolbox.org/welcome.html#kobotoolbox-components
# https://support.kobotoolbox.org/form_meta.html#additional-settings
# https://support.kobotoolbox.org/recording-interviews.html#setting-an-appropriate-audio-quality
# https://support.kobotoolbox.org/gps_questions.html#how-to-set-up-the-point-line-and-area-question-types
# https://support.kobotoolbox.org/export_download.html#export-types
# https://support.kobotoolbox.org/calculations_constraints_matrix.html
# https://support.kobotoolbox.org/hxl.html#how-to-use-hxl-in-an-xlsform
# https://support.kobotoolbox.org/collect_gps.html#collecting-data-using-the-gps-questions
# https://support.kobotoolbox.org/data-offline.html
# https://support.kobotoolbox.org/pulling_data_into_excelquery.html#step-1-get-the-synchronous-exports-url
# https://support.kobotoolbox.org/adding_skip_to_matrix.html
# https://support.kobotoolbox.org/form_meta.html#details
# https://support.kobotoolbox.org/transferring_forms.html
# https://support.kobotoolbox.org/quick_start.html
# https://support.kobotoolbox.org/export_download.html#advanced-options
# https://support.kobotoolbox.org/is_my_data_safe.html
# https://support.kobotoolbox.org/encrypting_forms.html#how-to-encrypt-xls-forms
# https://support.kobotoolbox.org/media.html#step-5-upload-media-files
# https://support.kobotoolbox.org/howto_edit_single_submissions.html
# https://support.kobotoolbox.org/dynamic_data_attachment.html#setting-up-for-dynamic-linking
# https://support.kobotoolbox.org/alternative_enketo.html#available-styles-in-xlsform
# https://support.kobotoolbox.org/group_repeat.html#controlling-the-loop-of-repetition-in-a-roster
# https://support.kobotoolbox.org/select_one_and_select_many.html
# https://support.kobotoolbox.org/troubleshooting_webforms.html#data-loss
# https://support.kobotoolbox.org/enketo.html#how-do-i-troubleshoot-enketo
# https://support.kobotoolbox.org/calculate_questions.html#list-of-available-math-operators
# https://support.kobotoolbox.org/external_file.html
# https://support.kobotoolbox.org/record_validation.html#what-are-the-statuses-that-you-can-assign-to-a-record
# https://support.kobotoolbox.org/photo_download.html
# https://support.kobotoolbox.org/validation_criteria.html
# https://support.kobotoolbox.org/collect_gps.html#troubleshooting
# https://support.kobotoolbox.org/archiving_projects.html#process-of-unarchiving
# https://support.kobotoolbox.org/unique_serial_numbers.html#approach-2-creating-unique-serial-numbers-from-selected-variables
# https://support.kobotoolbox.org/media.html#tips-tricks
# https://support.kobotoolbox.org/creating_account.html#troubleshooting
# https://support.kobotoolbox.org/question_types.html
# https://support.kobotoolbox.org/stuck_in_pending.html
# https://support.kobotoolbox.org/library_locking.html#terminology
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html#differences-between-kobocollect-odk-collect
# https://support.kobotoolbox.org/formbuilder.html#duplicating-a-question
# https://support.kobotoolbox.org/managing_permissions.html#row-level-permissions-for-users
# https://support.kobotoolbox.org/welcome.html#what-languages-are-supported
# https://support.kobotoolbox.org/kobocollect_on_android_latest.html
# https://support.kobotoolbox.org/text_and_note.html#considerations-when-using-text-questions
# https://support.kobotoolbox.org/group_repeat.html
# https://support.kobotoolbox.org/gps_questions.html#collecting-gps-points-in-the-background

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd

# Create a list to store the text files
texts=[]

# Get all the text files in the text directory
for file in os.listdir("text/" + domain + "/"):

    # Open the file and read the text
    with open("text/" + domain + "/" + file, "r") as f:
        text = f.read()

        # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
        texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))

# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/scraped.csv')
df.head()
# Out:
# /tmp/ipykernel_25991/2931785837.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   serie = serie.str.replace('\\n', ' ')
#                                                fname  \
# 0  otoolbox.org export gps.html#viewing your gps ...
# 1  otoolbox.org hxl.html#how to use the hxl featu...
# 2  otoolbox.org merging dataset excel power query...
# 3      otoolbox.org devices for data collection.html
# 4  otoolbox.org validation criteria.html#add vali...
#
#                                                 text
# 0  otoolbox.org export gps.html#viewing your gps ...
# 1  otoolbox.org hxl.html#how to use the hxl featu...
# 2  otoolbox.org merging dataset excel power query...
# 3  otoolbox.org devices for data collection.html....
# 4  otoolbox.org validation criteria.html#add vali...

# %%
import tiktoken

# Load the cl100k_base tokenizer which is designed to work with the ada-002 model
tokenizer = tiktoken.get_encoding("cl100k_base")

df = pd.read_csv('processed/scraped.csv', index_col=0)
df.columns = ['title', 'text']

# Tokenize the text and save the number of tokens to a new column
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
# Out:
# <Axes: >

# %%
max_tokens = 500

# Function to split the text into chunks of a maximum number of tokens
def split_into_many(text, max_tokens = max_tokens):

    # Split the text into sentences
    sentences = text.split('. ')

    # Get the number of tokens for each sentence
    n_tokens = [len(tokenizer.encode(" " + sentence)) for sentence in sentences]
    
    chunks = []
    tokens_so_far = 0
    chunk = []

    # Loop through the sentences and tokens joined together in a tuple
    for sentence, token in zip(sentences, n_tokens):

        # If the number of tokens so far plus the number of tokens in the current sentence is greater 
        # than the max number of tokens, then add the chunk to the list of chunks and reset
        # the chunk and tokens so far
        if tokens_so_far + token > max_tokens:
            chunks.append(". ".join(chunk) + ".")
            chunk = []
            tokens_so_far = 0

        # If the number of tokens in the current sentence is greater than the max number of 
        # tokens, go to the next sentence
        if token > max_tokens:
            continue

        # Otherwise, add the sentence to the chunk and add the number of tokens to the total
        chunk.append(sentence)
        tokens_so_far += token + 1

    return chunks
    

shortened = []

# Loop through the dataframe
for row in df.iterrows():

    # If the text is None, go to the next row
    if row[1]['text'] is None:
        continue

    # If the number of tokens is greater than the max number of tokens, split the text into chunks
    if row[1]['n_tokens'] > max_tokens:
        shortened += split_into_many(row[1]['text'])
    
    # Otherwise, add the text to the list of shortened texts
    else:
        shortened.append( row[1]['text'] )

# %%
df = pd.DataFrame(shortened, columns = ['text'])
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))
df.n_tokens.hist()
# Out:
# <Axes: >

# %%
import openai
import os
from dotenv import load_dotenv
import time

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")
delay = 60 / 59


def get_embedding(text):
    time.sleep(delay)
    return openai.Embedding.create(input=text, engine='text-embedding-ada-002')['data'][0]['embedding']


df['embeddings'] = df.text.apply(get_embedding)
df.to_csv('processed/embeddings.csv')
df.head()
# Out:
#                                                 text  n_tokens  \
# 0  otoolbox.org export gps.html#viewing your gps ...       490
# 1  How to share map data¶ You can share a map wit...        83
# 2  otoolbox.org hxl.html#how to use the hxl featu...       357
# 3  otoolbox.org merging dataset excel power query...       493
# 4  Data downloaded in XLS format should also show...       478
#
#                                           embeddings
# 0  [-0.0053034331649541855, 0.0070465197786688805...
# 1  [-0.007623978890478611, 0.0026974393986165524,...
# 2  [-0.011831359006464481, 0.022144991904497147, ...
# 3  [-0.008324231952428818, -0.000519840803463012,...
# 4  [-0.0013668457977473736, 0.008950849063694477,...

# %%
import pandas as pd
import numpy as np
from openai.embeddings_utils import distances_from_embeddings, cosine_similarity

df=pd.read_csv('processed/embeddings.csv', index_col=0)
df['embeddings'] = df['embeddings'].apply(eval).apply(np.array)

df.head()
# Out:
#                                                 text  n_tokens  \
# 0  otoolbox.org export gps.html#viewing your gps ...       490
# 1  How to share map data¶ You can share a map wit...        83
# 2  otoolbox.org hxl.html#how to use the hxl featu...       357
# 3  otoolbox.org merging dataset excel power query...       493
# 4  Data downloaded in XLS format should also show...       478
#
#                                           embeddings
# 0  [-0.0053034331649541855, 0.0070465197786688805...
# 1  [-0.007623978890478611, 0.0026974393986165524,...
# 2  [-0.011831359006464481, 0.022144991904497147, ...
# 3  [-0.008324231952428818, -0.000519840803463012,...
# 4  [-0.0013668457977473736, 0.008950849063694477,...

# %%
def create_context(
    question, df, max_len=1800, size="ada"
):
    """
    Create a context for a question by finding the most similar context from the dataframe
    """

    # Get the embeddings for the question
    q_embeddings = openai.Embedding.create(input=question, engine='text-embedding-ada-002')['data'][0]['embedding']

    # Get the distances from the embeddings
    df['distances'] = distances_from_embeddings(q_embeddings, df['embeddings'].values, distance_metric='cosine')


    returns = []
    cur_len = 0

    # Sort by distance and add the text to the context until the context is too long
    for i, row in df.sort_values('distances', ascending=True).iterrows():
        
        # Add the length of the text to the current length
        cur_len += row['n_tokens'] + 4
        
        # If the context is too long, break
        if cur_len > max_len:
            break
        
        # Else add it to the text that is being returned
        returns.append(row["text"])

    # Return the context
    return "\n\n###\n\n".join(returns)

def answer_question(
    df,
    model="text-davinci-003",
    question="Am I allowed to publish model outputs to Twitter, without a human review?",
    max_len=1800,
    size="ada",
    debug=False,
    max_tokens=150,
    stop_sequence=None
):
    """
    Answer a question based on the most similar context from the dataframe texts
    """
    context = create_context(
        question,
        df,
        max_len=max_len,
        size=size,
    )
    # If debug, print the raw model response
    if debug:
        print("Context:\n" + context)
        print("\n\n")

    try:
        # Create a completions using the question and context
        response = openai.Completion.create(
            prompt=f"Answer the question based on the context below, and if the question can't be answered based on the context, say \"I don't know\"\n\nContext: {context}\n\n---\n\nQuestion: {question}\nAnswer:",
            temperature=0,
            max_tokens=max_tokens,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            stop=stop_sequence,
            model=model,
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

# %%
answer_question(df, question="What can I do with Kobo Toolbox?", debug=False)
# Out:
# 'KoboToolbox allows you to easily develop digital data collection forms that work on both mobile devices and web browsers. Creating forms is quick and simple, thanks to our easy-to-use online form builder. You can also use the XLSForm specification and upload your files directly to the platform, which will provide you with the flexibility to build more complex and customizable forms. You can also manage your data by aggregating the data collected from different devices, accessible through the KoboToolbox interface. Additionally, you can share projects with other users within the same KoboToolbox server, control which parts of the project other people can have access to using granular sharing permissions, and also who can send submissions to the project. You are also able'

# %%
answer_question(df, question="What is our newest embeddings model?")
# Out:
# 'The newest embeddings model is text-embedding-ada-002.'
